# %% [markdown]
# ## Pre-processing:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16, 6)

date_parser = lambda dates: pd.datetime.strptime(dates, "%Y-%m-%d") 

data_daily  = pd.read_csv("ASX200Daily.csv",parse_dates = ["Date"], 
                         index_col = 'Date', date_parser = date_parser) 

data_monthly = pd.read_csv("ASX200Monthly.csv",parse_dates = ["Date"], 
                         index_col = 'Date', date_parser = date_parser)


close_daily = data_daily["Close"]
close_monthly = data_monthly["Close"]


close_daily.fillna(method='ffill', inplace=True)
#close_monthly.fillna(method='ffill', inplace=True)
close_monthly.dropna(inplace=True)

# %% [markdown]
# ## Exploratory Time Series:

# %%
plt.figure(figsize = (16,5))
plt.plot(close_daily)
plt.grid()
plt.title("U")
plt.xlabel("Time")
plt.ylabel("Close")
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Close')

# %%
plt.figure(figsize = (16,5))
plt.plot(close_monthly)
plt.grid()
plt.title("U")
plt.xlabel("Time")
plt.ylabel("Close")
# Out:
# Text(0, 0.5, 'Close')

# %%
close_daily.describe()
# Out:
# count    4821.000000
# mean     4628.595748
# std      1011.721356
# min      2700.399902
# 25%      3557.399902
# 50%      4739.000000
# 75%      5452.500000
# max      6828.700195
# Name: Close, dtype: float64

# %%
close_monthly.describe()
# Out:
# count     228.000000
# mean     4659.366239
# std      1015.291733
# min      2800.899902
# 25%      3707.975037
# 50%      4758.649902
# 75%      5483.850098
# max      6754.100098
# Name: Close, dtype: float64

# %%
diff_close_daily = pd.Series.diff(close_daily)
diff_close_monthly = pd.Series.diff(close_monthly)
diff_close_daily.dropna(inplace = True)
diff_close_monthly.dropna(inplace = True)

# %%
plt.figure()
plt.plot(diff_close_daily)
plt.title("1 step difference Daily close")
plt.xlabel("Time")
plt.ylabel("Difference")


plt.figure()
plt.plot(diff_close_monthly)
plt.title("1 step difference monthly close")
plt.xlabel("Time")
plt.ylabel("Difference")
# Out:
# Text(0, 0.5, 'Difference')

# %%
import statsmodels as sm 
import statsmodels.api as smt

smt.graphics.tsa.plot_acf(close_daily, lags = 30, alpha = 0.05)
smt.graphics.tsa.plot_pacf(close_daily, lags=30, alpha=0.05)
plt.show()

# %%
smt.graphics.tsa.plot_acf(diff_close_daily, lags = 30, alpha = 0.05)
smt.graphics.tsa.plot_pacf(diff_close_daily, lags=30, alpha=0.05)

# %%
smt.graphics.tsa.plot_acf(close_monthly, lags = 30, alpha = 0.05)
smt.graphics.tsa.plot_pacf(close_monthly, lags=30, alpha=0.05)
plt.show()

# %%
smt.graphics.tsa.plot_acf(diff_close_monthly, lags = 30, alpha = 0.05)
smt.graphics.tsa.plot_pacf(diff_close_monthly, lags=30, alpha=0.05)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
close_daily_normalize = scaler.fit_transform(close_daily.values.reshape(-1,1))
close_monthly_normalize = scaler.fit_transform(close_monthly.values.reshape(-1,1))




close_daily_normalize_2 = close_daily_normalize.copy()
close_daily_normalize_2 = pd.Series(close_daily_normalize_2.flatten(), index =close_daily.index )
close_monthly_normalize_2 = close_monthly_normalize.copy()
close_monthly_normalize_2 = pd.Series(close_monthly_normalize_2.flatten(), index =close_monthly.index )

plt.figure(figsize = (16,5))
plt.plot(close_daily_normalize_2)
plt.title("MinMaxScaler daily close")
plt.xlabel("Time")
plt.ylabel("Close")


plt.figure(figsize = (16,5))
plt.plot(close_monthly_normalize_2)
plt.title("MinMaxScaler monthly close")
plt.xlabel("Time")
plt.ylabel("Close")
# Out:
# Text(0, 0.5, 'Close')

# %% [markdown]
# ## Benchmark Model:

# %% [markdown]
# ### Daily

# %%
import math
validation_size = 5
train_size = len(close_daily) - validation_size
close_daily
# Out:
# Date
# 2000-03-31    3133.300049
# 2000-04-03    3191.000000
# 2000-04-04    3176.800049
# 2000-04-05    3155.399902
# 2000-04-06    3157.100098
# 2000-04-07    3182.000000
# 2000-04-10    3201.399902
# 2000-04-11    3173.000000
# 2000-04-12    3148.699951
# 2000-04-13    3099.699951
# 2000-04-14    3111.899902
# 2000-04-17    2943.899902
# 2000-04-18    3010.300049
# 2000-04-19    3069.199951
# 2000-04-20    3069.199951
# 2000-04-21    3069.199951
# 2000-04-24    3069.199951
# 2000-04-25    3069.199951
# 2000-04-26    3117.300049
# 2000-04-27    3106.300049
# 2000-04-28    3115.800049
# 2000-05-01    3102.000000
# 2000-05-02    3131.100098
# 2000-05-03    3107.500000
# 2000-05-04    3053.800049
# 2000-05-05    3107.199951
# 2000-05-08    3106.199951
# 2000-05-09    3086.100098
# 2000-05-10    3043.399902
# 2000-05-11    2996.399902
#                  ...
# 2019-01-17    5879.600098
# 2019-01-20    5890.399902
# 2019-01-21    5858.799805
# 2019-01-22    5843.700195
# 2019-01-23    5865.700195
# 2019-01-24    5905.600098
# 2019-01-28    5874.200195
# 2019-01-29    5886.700195
# 2019-01-30    5864.700195
# 2019-01-31    5862.799805
# 2019-02-03    5891.200195
# 2019-02-04    6005.899902
# 2019-02-05    6026.100098
# 2019-02-06    6092.500000
# 2019-02-07    6071.500000
# 2019-02-10    6060.799805
# 2019-02-11    6079.100098
# 2019-02-12    6063.600098
# 2019-02-13    6059.399902
# 2019-02-14    6066.100098
# 2019-02-17    6089.799805
# 2019-02-18    6106.899902
# 2019-02-19    6096.500000
# 2019-02-20    6139.200195
# 2019-02-21    6167.299805
# 2019-02-24    6186.299805
# 2019-02-25    6128.399902
# 2019-02-26    6150.299805
# 2019-02-27    6169.000000
# 2019-03-01    6192.700195
# Name: Close, Length: 4821, dtype: float64

# %%
train_close_daily = close_daily[:-validation_size]
validation_close_daily  =  close_daily[-validation_size:]
train_close_daily
# Out:
# Date
# 2000-03-31    3133.300049
# 2000-04-03    3191.000000
# 2000-04-04    3176.800049
# 2000-04-05    3155.399902
# 2000-04-06    3157.100098
# 2000-04-07    3182.000000
# 2000-04-10    3201.399902
# 2000-04-11    3173.000000
# 2000-04-12    3148.699951
# 2000-04-13    3099.699951
# 2000-04-14    3111.899902
# 2000-04-17    2943.899902
# 2000-04-18    3010.300049
# 2000-04-19    3069.199951
# 2000-04-20    3069.199951
# 2000-04-21    3069.199951
# 2000-04-24    3069.199951
# 2000-04-25    3069.199951
# 2000-04-26    3117.300049
# 2000-04-27    3106.300049
# 2000-04-28    3115.800049
# 2000-05-01    3102.000000
# 2000-05-02    3131.100098
# 2000-05-03    3107.500000
# 2000-05-04    3053.800049
# 2000-05-05    3107.199951
# 2000-05-08    3106.199951
# 2000-05-09    3086.100098
# 2000-05-10    3043.399902
# 2000-05-11    2996.399902
#                  ...
# 2019-01-10    5774.600098
# 2019-01-13    5773.399902
# 2019-01-14    5814.600098
# 2019-01-15    5835.200195
# 2019-01-16    5850.100098
# 2019-01-17    5879.600098
# 2019-01-20    5890.399902
# 2019-01-21    5858.799805
# 2019-01-22    5843.700195
# 2019-01-23    5865.700195
# 2019-01-24    5905.600098
# 2019-01-28    5874.200195
# 2019-01-29    5886.700195
# 2019-01-30    5864.700195
# 2019-01-31    5862.799805
# 2019-02-03    5891.200195
# 2019-02-04    6005.899902
# 2019-02-05    6026.100098
# 2019-02-06    6092.500000
# 2019-02-07    6071.500000
# 2019-02-10    6060.799805
# 2019-02-11    6079.100098
# 2019-02-12    6063.600098
# 2019-02-13    6059.399902
# 2019-02-14    6066.100098
# 2019-02-17    6089.799805
# 2019-02-18    6106.899902
# 2019-02-19    6096.500000
# 2019-02-20    6139.200195
# 2019-02-21    6167.299805
# Name: Close, Length: 4816, dtype: float64

# %%
len(train_close_daily)
# Out:
# 4816

# %%
validation_close_daily
# Out:
# Date
# 2019-02-24    6186.299805
# 2019-02-25    6128.399902
# 2019-02-26    6150.299805
# 2019-02-27    6169.000000
# 2019-03-01    6192.700195
# Name: Close, dtype: float64

# %%
import time
# validate_time = time.strptime("2019-02-24","%Y-%m-%d")
validate_time = validation_close_daily.index[0]

# %% [markdown]
# ###

# %%
close_daily_log = np.log(close_daily)
train_close_daily_log = np.log(train_close_daily)
validation_close_daily_log = np.log(validation_close_daily)

plt.figure(figsize = (16,5))
plt.plot(train_close_daily_log,label = "")
plt.plot(validation_close_daily_log,label="")

#plt.axvline(validate_time,0,1)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from sklearn.metrics import mean_squared_error
def rmse(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %%
# decomposition method,
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(train_close_daily_log, model = "additive",freq=365,two_sided=False)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
decomposition.plot()
plt.show()

# %%
np.arange(1,train_size+1)
# Out:
# array([   1,    2,    3, ..., 4814, 4815, 4816])

# %%
from sklearn.linear_model import LinearRegression
X = np.arange(1,train_size+1)
y = train_close_daily_log-seasonal
X = np.reshape(X, (len(X), 1))
y = y.values.reshape(len(y),1)
#    
lm = LinearRegression()
lm.fit(X, y)
#    
# The coefficients
print("Coefficients: {0}".format(lm.coef_))
# The intercept
print("Intercept: {0}".format(lm.intercept_))
print("Total model: y = {0} + {1} X".format(lm.intercept_,lm.coef_[0]))

print("Variance score (R^2): {0:.2f}".format(lm.score(X, y)))
# Out:
# Coefficients: [[0.00012791]]
# Intercept: [8.10654803]
# Total model: y = [8.10654803] + [0.00012791] X
# Variance score (R^2): 0.61

# %%
len(close_daily_log)
# Out:
# 4821

# %%
seasonal_indice = seasonal[:365]
seasonal_forcast = np.tile(seasonal_indice,14)[:len(close_daily_log)]
len(seasonal_forcast)
# Out:
# 4821

# %%
trend_cycle = lm.predict(np.reshape(np.arange(1,len(close_daily_log)+1), (len(close_daily_log),1)))
linear_seasonal_total = pd.Series( (trend_cycle + np.reshape(seasonal_forcast, (len(close_daily_log),1))).reshape(len(close_daily_log),) )
linear_seasonal_total.index = close_daily.index


plt.figure(figsize = (16,5))
plt.plot(X, y, label = "reestimated_seasonally_adjusted")
plt.plot(trend_cycle, linestyle='--', label="Forecast_trend")
plt.legend()
plt.show(block=False)

# %%
plt.figure(figsize = (16,5))
plt.plot(np.arange(1,len(close_daily_log)+1),close_daily_log,label = "oringinal data")
plt.plot(np.arange(1,len(close_daily_log)+1),linear_seasonal_total,label="linear_seasonal_forecast")

#plt.axvline(validate_time,0,1)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (16,5))
plt.plot(close_daily_log[-100:],label = "oringinal data")
plt.plot(linear_seasonal_total[-100:-6] )

plt.plot(linear_seasonal_total[-7:],linestyle='--',label="linear_seasonal_forecast")
plt.legend()
plt.show()

# %%
def sse(x, y): # sse: sum of squared error
    return np.sum(np.power(x - y, 2))
forecast_set = np.exp(linear_seasonal_total[-validation_size:])
validation_set = np.exp(close_daily_log[-validation_size:].values)
print("SSE for decomposition method \n",sse(forecast_set,validation_set))
# Out:
# SSE for decomposition method
#  216262.35638566618

# %%
# Holt

# %%
from statsmodels.tsa.holtwinters import Holt
fit1 = Holt(train_close_daily).fit(optimized = True)
smooth_Holt = fit1.fittedvalues


results = pd.DataFrame(index=[r"$\alpha$", 
                              r"$\beta$", 
                              r"$\phi$",  # damped value
                              r"$\gamma$", 
                              r"$l_0$", 
                              "$b_0$", 
                              "SSE"])
params = ['smoothing_level', 
          'smoothing_slope', 
          'damping_slope', 
          'smoothing_seasonal', 
          'initial_level', 
          'initial_slope']

results["Additive"] = [fit1.params[p] for p in params] + [fit1.sse]
results
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#               Additive
# $\alpha$  9.647889e-01
# $\beta$   0.000000e+00
# $\phi$             NaN
# $\gamma$           NaN
# $l_0$     3.134668e+03
# $b_0$     6.296182e-01
# SSE       1.000626e+07

# %%
fit1.sse
# Out:
# 10006259.821413716

# %%
forecast_set = pd.Series(fit1.forecast(validation_size))

forecast_set.index = validation_close_daily.index


plt.figure(figsize = (16,5))
plt.plot(close_daily)

plt.plot(smooth_Holt,linestyle='--')
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
plt.figure(figsize = (16,5))
plt.plot(fit1.resid)

# %%
print("RMSE of train set for HOLT\n",rmse(smooth_Holt,train_close_daily))
# Out:
# RMSE of train set for HOLT
#  45.581923576545826

# %%
plt.figure(figsize = (16,5))
plt.plot(close_daily[-50:])
plt.plot(smooth_Holt[-45:])

plt.plot(forecast_set)

# %%
validation_set = np.exp(close_daily_log[-validation_size:].values)
print("RMSE for Holt’s linear method\n",rmse(forecast_set,validation_set))
# Out:
# RMSE for Holt’s linear method
#  23.53221325836051

# %%
#Holt’s linear method
from statsmodels.tsa.holtwinters import ExponentialSmoothing

fit = ExponentialSmoothing(train_close_daily, trend = 'add').fit()
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
results = pd.DataFrame(index=[r"$\alpha$", 
                              r"$\beta$", 
                              r"$\phi$",  # damped value
                              r"$\gamma$", 
                              r"$l_0$", 
                              "$b_0$", 
                              "SSE"])
params = ['smoothing_level', 
          'smoothing_slope', 
          'damping_slope', 
          'smoothing_seasonal', 
          'initial_level', 
          'initial_slope']

results["Additive"] = [fit.params[p] for p in params] + [fit.sse]
results
# Out:
#               Additive
# $\alpha$  9.647889e-01
# $\beta$   0.000000e+00
# $\phi$             NaN
# $\gamma$           NaN
# $l_0$     3.134668e+03
# $b_0$     6.296182e-01
# SSE       1.000626e+07

# %%
forecast_set = fit.forecast(validation_size)
forecast_set.index = validation_close_daily.index
smooth_add = fit.fittedvalues
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
forecast_set
# Out:
# Date
# 2019-02-24    6166.910470
# 2019-02-25    6167.540088
# 2019-02-26    6168.169706
# 2019-02-27    6168.799324
# 2019-03-01    6169.428942
# dtype: float64

# %%
plt.figure(figsize = (16,5))
plt.plot(close_daily)

plt.plot(smooth_add,linestyle='--')

# %%
print("SSE of train set for ARIMA\n",sse(smooth_add,train_close_daily))
# Out:
# SSE of train set for ARIMA
#  10006259.821413718

# %%
plt.figure(figsize = (16,5))
plt.plot(close_daily[-50:])
plt.plot(smooth_add[-43:])

plt.plot(forecast_set)

# %%
validation_set = np.exp(close_daily_log[-validation_size:].values)
print("SSE for Holt’s linear method\n",sse(forecast_set,validation_set))
# Out:
# SSE for Holt’s linear method
#  2768.825304184791

# %% [markdown]
# ## Build Advanced Models:

# %%
#ARIMA
plt.figure(figsize = (16,5))
plt.grid()
plt.plot(train_close_daily_log)

# %%
smt.graphics.tsa.plot_acf(train_close_daily_log, lags=30, alpha = 0.05)
smt.graphics.tsa.plot_pacf(train_close_daily_log, lags=30, alpha = 0.05)

# %%
train_close_daily_log_diff = train_close_daily_log.diff()
train_close_daily_log_diff.dropna(inplace = True)
plt.figure(figsize = (16,5))
plt.plot(train_close_daily_log_diff)

# %%
smt.graphics.tsa.plot_acf(train_close_daily_log_diff, lags=30, alpha = 0.05)
smt.graphics.tsa.plot_pacf(train_close_daily_log_diff, lags=30, alpha = 0.05)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
#Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used']) 
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value 
    print(dfoutput)

# %%
test_stationarity(train_close_daily_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -42.112678
# p-value                           0.000000
# #Lags Used                        2.000000
# Number of Observations Used    4812.000000
# Critical Value (1%)              -3.431710
# Critical Value (5%)              -2.862141
# Critical Value (10%)             -2.567090
# dtype: float64

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 16,6

import warnings
warnings.simplefilter('ignore')


import statsmodels.tsa.stattools as st
order = st.arma_order_select_ic(train_close_daily_log_diff, max_ar = 5, max_ma = 5, ic=['aic'])
print(order.aic_min_order)
# Out:
# (4, 3)

# %%
from statsmodels.tsa.arima_model import ARIMA

p,q = order.aic_min_order[0], order.aic_min_order[1]
model_AIC = ARIMA(train_close_daily_log, order = (p, 1, q))  
results_AIC_ARIMA = model_AIC.fit(disp = -1)

# %%
residuals = pd.DataFrame(results_AIC_ARIMA.resid) 

# check the residual
plt.figure() 
plt.plot(residuals)
plt.title('ARIMA(3,1,4) RSS: %.4f'% sum((results_AIC_ARIMA.resid.values)**2)); # residual sum of square

# %%
fitted_log = results_AIC_ARIMA.predict(typ = 'levels', dynamic = False)

# Actual vs Fitted 
results_AIC_ARIMA.plot_predict(dynamic = False) 
plt.show()

# %%
fitted = np.exp(fitted_log)

# %%
forecast, stderr, conf_int = results_AIC_ARIMA.forecast(steps = validation_size)
forecast_set = pd.Series(np.exp(forecast), index = validation_close_daily.index)
plt.figure()
plt.plot(close_daily)
plt.plot(fitted)

plt.plot(forecast_set)

# %%
train_close_daily
# Out:
# Date
# 2000-03-31    3133.300049
# 2000-04-03    3191.000000
# 2000-04-04    3176.800049
# 2000-04-05    3155.399902
# 2000-04-06    3157.100098
# 2000-04-07    3182.000000
# 2000-04-10    3201.399902
# 2000-04-11    3173.000000
# 2000-04-12    3148.699951
# 2000-04-13    3099.699951
# 2000-04-14    3111.899902
# 2000-04-17    2943.899902
# 2000-04-18    3010.300049
# 2000-04-19    3069.199951
# 2000-04-20    3069.199951
# 2000-04-21    3069.199951
# 2000-04-24    3069.199951
# 2000-04-25    3069.199951
# 2000-04-26    3117.300049
# 2000-04-27    3106.300049
# 2000-04-28    3115.800049
# 2000-05-01    3102.000000
# 2000-05-02    3131.100098
# 2000-05-03    3107.500000
# 2000-05-04    3053.800049
# 2000-05-05    3107.199951
# 2000-05-08    3106.199951
# 2000-05-09    3086.100098
# 2000-05-10    3043.399902
# 2000-05-11    2996.399902
#                  ...
# 2019-01-10    5774.600098
# 2019-01-13    5773.399902
# 2019-01-14    5814.600098
# 2019-01-15    5835.200195
# 2019-01-16    5850.100098
# 2019-01-17    5879.600098
# 2019-01-20    5890.399902
# 2019-01-21    5858.799805
# 2019-01-22    5843.700195
# 2019-01-23    5865.700195
# 2019-01-24    5905.600098
# 2019-01-28    5874.200195
# 2019-01-29    5886.700195
# 2019-01-30    5864.700195
# 2019-01-31    5862.799805
# 2019-02-03    5891.200195
# 2019-02-04    6005.899902
# 2019-02-05    6026.100098
# 2019-02-06    6092.500000
# 2019-02-07    6071.500000
# 2019-02-10    6060.799805
# 2019-02-11    6079.100098
# 2019-02-12    6063.600098
# 2019-02-13    6059.399902
# 2019-02-14    6066.100098
# 2019-02-17    6089.799805
# 2019-02-18    6106.899902
# 2019-02-19    6096.500000
# 2019-02-20    6139.200195
# 2019-02-21    6167.299805
# Name: Close, Length: 4816, dtype: float64

# %%
print("RMSE of train set for ARIMA\n",rmse(fitted,train_close_daily[:-1]))
# Out:
# RMSE of train set for ARIMA
#  3.292552858854617

# %%
plt.figure(figsize = (20,5))
plt.plot(close_daily[-50:])
plt.plot(fitted[-43:])

plt.plot(forecast_set)

# %%
print("RMSE of test set for ARIMA\n",rmse(forecast_set,validation_set))
# Out:
# RMSE of test set for ARIMA
#  23.10797958840657

# %%
# Deep Neural Networks and Recurrent Neural Networks

import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.layers.core import Dense
from keras.models import Sequential

np.random.seed(0)
# Out:
# Using TensorFlow backend.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
close_daily_normalize = scaler.fit_transform(close_daily.values.reshape(-1,1))
close_monthly_normalize = scaler.fit_transform(close_monthly.values.reshape(-1,1))

plt.figure(figsize = (16,5))
plt.plot(close_daily_normalize)
plt.title("MinMaxScaler daily close")
plt.xlabel("Time")
plt.ylabel("Close")


plt.figure(figsize = (16,5))
plt.plot(close_monthly_normalize)
plt.title("MinMaxScaler monthly close")
plt.xlabel("Time")
plt.ylabel("Close")
# Out:
# Text(0, 0.5, 'Close')

# %%
data = close_daily_normalize
time_window = 5
Xall, Yall = [], []
for i in range(time_window, len(data)):
    Xall.append(data[i-time_window:i, 0])
    Yall.append(data[i, 0])
    
Xall = np.array(Xall) # Convert them from list to array
Yall = np.array(Yall)
test_size = 5
train_size =  len(Xall) - test_size

Xtrain = Xall[:train_size, :]
Ytrain = Yall[:train_size]
Xtest = Xall[-test_size:, :]
Ytest = Yall[-test_size:]

# %%
model = Sequential()
model.add(Dense(20, input_dim=time_window,activation='relu'))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error',optimizer='adam')
model.fit(Xtrain, Ytrain, epochs=100, batch_size=2,verbose=2, validation_split=0.05)
# Out:
# Train on 4570 samples, validate on 241 samples
# Epoch 1/100
#  - 2s - loss: 0.0042 - val_loss: 2.0154e-04
# Epoch 2/100
#  - 2s - loss: 1.9781e-04 - val_loss: 2.2113e-04
# Epoch 3/100
#  - 2s - loss: 1.9659e-04 - val_loss: 2.7188e-04
# Epoch 4/100
#  - 2s - loss: 2.0266e-04 - val_loss: 1.1430e-04
# Epoch 5/100
#  - 2s - loss: 1.9343e-04 - val_loss: 2.7415e-04
# Epoch 6/100
#  - 2s - loss: 1.8912e-04 - val_loss: 1.4244e-04
# Epoch 7/100
#  - 2s - loss: 1.8333e-04 - val_loss: 1.1112e-04
# Epoch 8/100
#  - 2s - loss: 1.8404e-04 - val_loss: 5.8787e-04
# Epoch 9/100
#  - 2s - loss: 1.7193e-04 - val_loss: 1.5056e-04
# Epoch 10/100
#  - 2s - loss: 1.7496e-04 - val_loss: 2.0214e-04
# Epoch 11/100
#  - 2s - loss: 1.7438e-04 - val_loss: 1.0721e-04
# Epoch 12/100
#  - 2s - loss: 1.7462e-04 - val_loss: 2.6369e-04
# Epoch 13/100
#  - 2s - loss: 1.6737e-04 - val_loss: 1.7450e-04
# Epoch 14/100
#  - 2s - loss: 1.7599e-04 - val_loss: 1.2443e-04
# Epoch 15/100
#  - 2s - loss: 1.6240e-04 - val_loss: 1.6333e-04
# Epoch 16/100
#  - 2s - loss: 1.6742e-04 - val_loss: 2.4730e-04
# Epoch 17/100
#  - 2s - loss: 1.6804e-04 - val_loss: 1.1735e-04
# Epoch 18/100
#  - 2s - loss: 1.6148e-04 - val_loss: 1.0956e-04
# Epoch 19/100
#  - 2s - loss: 1.6995e-04 - val_loss: 3.0125e-04
# Epoch 20/100
#  - 2s - loss: 1.5820e-04 - val_loss: 1.0212e-04
# Epoch 21/100
#  - 2s - loss: 1.6819e-04 - val_loss: 1.7656e-04
# Epoch 22/100
#  - 2s - loss: 1.6126e-04 - val_loss: 2.7093e-04
# Epoch 23/100
#  - 2s - loss: 1.5759e-04 - val_loss: 1.8472e-04
# Epoch 24/100
#  - 2s - loss: 1.6115e-04 - val_loss: 2.1104e-04
# Epoch 25/100
#  - 2s - loss: 1.5840e-04 - val_loss: 1.0325e-04
# Epoch 26/100
#  - 2s - loss: 1.6530e-04 - val_loss: 1.0127e-04
# Epoch 27/100
#  - 2s - loss: 1.6439e-04 - val_loss: 1.1437e-04
# Epoch 28/100
#  - 2s - loss: 1.5736e-04 - val_loss: 1.1705e-04
# Epoch 29/100
#  - 2s - loss: 1.6073e-04 - val_loss: 1.1627e-04
# Epoch 30/100
#  - 2s - loss: 1.6441e-04 - val_loss: 1.0448e-04
# Epoch 31/100
#  - 2s - loss: 1.6075e-04 - val_loss: 2.2147e-04
# Epoch 32/100
#  - 2s - loss: 1.5714e-04 - val_loss: 3.6077e-04
# Epoch 33/100
#  - 2s - loss: 1.6303e-04 - val_loss: 1.7386e-04
# Epoch 34/100
#  - 2s - loss: 1.5643e-04 - val_loss: 1.3909e-04
# Epoch 35/100
#  - 2s - loss: 1.6225e-04 - val_loss: 3.1824e-04
# Epoch 36/100
#  - 2s - loss: 1.5749e-04 - val_loss: 1.8922e-04
# Epoch 37/100
#  - 2s - loss: 1.5492e-04 - val_loss: 1.1243e-04
# Epoch 38/100
#  - 2s - loss: 1.5981e-04 - val_loss: 1.2902e-04
# Epoch 39/100
#  - 2s - loss: 1.5887e-04 - val_loss: 1.8865e-04
# Epoch 40/100
#  - 2s - loss: 1.6291e-04 - val_loss: 1.7228e-04
# Epoch 41/100
#  - 2s - loss: 1.5495e-04 - val_loss: 3.2588e-04
# Epoch 42/100
#  - 2s - loss: 1.5371e-04 - val_loss: 1.0149e-04
# Epoch 43/100
#  - 2s - loss: 1.6148e-04 - val_loss: 1.3265e-04
# Epoch 44/100
#  - 2s - loss: 1.5514e-04 - val_loss: 1.0633e-04
# Epoch 45/100
#  - 2s - loss: 1.5168e-04 - val_loss: 1.2627e-04
# Epoch 46/100
#  - 2s - loss: 1.5692e-04 - val_loss: 1.0413e-04
# Epoch 47/100
#  - 2s - loss: 1.5960e-04 - val_loss: 1.9715e-04
# Epoch 48/100
#  - 2s - loss: 1.5185e-04 - val_loss: 1.0917e-04
# Epoch 49/100
#  - 2s - loss: 1.5733e-04 - val_loss: 1.1035e-04
# Epoch 50/100
#  - 2s - loss: 1.5692e-04 - val_loss: 2.0503e-04
# Epoch 51/100
#  - 2s - loss: 1.5408e-04 - val_loss: 1.6435e-04
# Epoch 52/100
#  - 2s - loss: 1.5703e-04 - val_loss: 1.4032e-04
# Epoch 53/100
#  - 2s - loss: 1.5951e-04 - val_loss: 1.5684e-04
# Epoch 54/100
#  - 2s - loss: 1.5855e-04 - val_loss: 1.1514e-04
# Epoch 55/100
#  - 2s - loss: 1.5234e-04 - val_loss: 1.4595e-04
# Epoch 56/100
#  - 2s - loss: 1.5502e-04 - val_loss: 1.1667e-04
# Epoch 57/100
#  - 2s - loss: 1.5581e-04 - val_loss: 1.0119e-04
# Epoch 58/100
#  - 2s - loss: 1.4896e-04 - val_loss: 1.0183e-04
# Epoch 59/100
#  - 2s - loss: 1.5494e-04 - val_loss: 1.8165e-04
# Epoch 60/100
#  - 2s - loss: 1.5727e-04 - val_loss: 2.1763e-04
# Epoch 61/100
#  - 2s - loss: 1.5507e-04 - val_loss: 2.2360e-04
# Epoch 62/100
#  - 2s - loss: 1.5559e-04 - val_loss: 1.0269e-04
# Epoch 63/100
#  - 2s - loss: 1.5615e-04 - val_loss: 1.1546e-04
# Epoch 64/100
#  - 2s - loss: 1.5236e-04 - val_loss: 1.0617e-04
# Epoch 65/100
#  - 2s - loss: 1.4926e-04 - val_loss: 1.6367e-04
# Epoch 66/100
#  - 2s - loss: 1.5311e-04 - val_loss: 3.0091e-04
# Epoch 67/100
#  - 2s - loss: 1.5706e-04 - val_loss: 4.9458e-04
# Epoch 68/100
#  - 2s - loss: 1.4944e-04 - val_loss: 1.1874e-04
# Epoch 69/100
#  - 2s - loss: 1.5165e-04 - val_loss: 1.0208e-04
# Epoch 70/100
#  - 2s - loss: 1.5367e-04 - val_loss: 3.5117e-04
# Epoch 71/100
#  - 2s - loss: 1.4829e-04 - val_loss: 2.0726e-04
# Epoch 72/100
#  - 2s - loss: 1.5110e-04 - val_loss: 1.4530e-04
# Epoch 73/100
#  - 2s - loss: 1.5127e-04 - val_loss: 1.3104e-04
# Epoch 74/100
#  - 2s - loss: 1.5289e-04 - val_loss: 1.3032e-04
# Epoch 75/100
#  - 2s - loss: 1.4889e-04 - val_loss: 1.1808e-04
# Epoch 76/100
#  - 2s - loss: 1.5804e-04 - val_loss: 1.0778e-04
# Epoch 77/100
#  - 2s - loss: 1.5147e-04 - val_loss: 1.4378e-04
# Epoch 78/100
#  - 2s - loss: 1.4999e-04 - val_loss: 1.1433e-04
# Epoch 79/100
#  - 2s - loss: 1.4694e-04 - val_loss: 1.4665e-04
# Epoch 80/100
#  - 2s - loss: 1.5225e-04 - val_loss: 1.7111e-04
# Epoch 81/100
#  - 2s - loss: 1.4933e-04 - val_loss: 1.5863e-04
# Epoch 82/100
#  - 2s - loss: 1.5119e-04 - val_loss: 1.1116e-04
# Epoch 83/100
#  - 2s - loss: 1.4969e-04 - val_loss: 1.0855e-04
# Epoch 84/100
#  - 2s - loss: 1.5144e-04 - val_loss: 1.8537e-04
# Epoch 85/100
#  - 2s - loss: 1.5055e-04 - val_loss: 1.0404e-04
# Epoch 86/100
#  - 2s - loss: 1.5025e-04 - val_loss: 1.4193e-04
# Epoch 87/100
#  - 2s - loss: 1.4679e-04 - val_loss: 9.9995e-05
# Epoch 88/100
#  - 2s - loss: 1.4871e-04 - val_loss: 1.7869e-04
# Epoch 89/100
#  - 2s - loss: 1.5082e-04 - val_loss: 1.8974e-04
# Epoch 90/100
#  - 2s - loss: 1.5322e-04 - val_loss: 1.0004e-04
# Epoch 91/100
#  - 2s - loss: 1.5002e-04 - val_loss: 1.2986e-04
# Epoch 92/100
#  - 2s - loss: 1.4596e-04 - val_loss: 1.7702e-04
# Epoch 93/100
#  - 2s - loss: 1.4712e-04 - val_loss: 9.9446e-05
# Epoch 94/100
#  - 2s - loss: 1.4447e-04 - val_loss: 1.5509e-04
# Epoch 95/100
#  - 2s - loss: 1.4623e-04 - val_loss: 1.1508e-04
# Epoch 96/100
#  - 2s - loss: 1.4840e-04 - val_loss: 1.0385e-04
# Epoch 97/100
#  - 2s - loss: 1.4603e-04 - val_loss: 1.0057e-04
# Epoch 98/100
#  - 2s - loss: 1.5019e-04 - val_loss: 3.7351e-04
# Epoch 99/100
#  - 2s - loss: 1.5355e-04 - val_loss: 9.9568e-05
# Epoch 100/100
#  - 2s - loss: 1.4574e-04 - val_loss: 9.9541e-05

# %%
allPredict = model.predict(Xall)
allPredictPlot = scaler.inverse_transform(allPredict)
plt.figure()
plt.plot(scaler.inverse_transform(data), label='True Data')
plt.plot(np.arange(time_window, len(data)),allPredictPlot, label='One-Step Prediction')
plt.legend()

# %%
Ytrain_ = scaler.inverse_transform(Ytrain.reshape(-1, 1))
allPredict_ = scaler.inverse_transform(allPredict[:train_size,0].reshape(-1, 1))
print("RMSE of train set for NN\n",rmse(Ytrain_,allPredict_))
# Out:
# RMSE of train set for NN
#  43.71106070639891

# %%
dynamic_prediction = np.copy(data[:len(data) - test_size])
for i in range(len(data) - test_size, len(data)):
    last_feature = np.reshape(dynamic_prediction[i-time_window:i], (1,time_window))
    next_pred = model.predict(last_feature)
    dynamic_prediction = np.append(dynamic_prediction, next_pred)
    
dynamic_prediction = dynamic_prediction.reshape(-1,1)
dynamic_prediction = scaler.inverse_transform(dynamic_prediction)

# %%
plt.figure()
plt.plot(scaler.inverse_transform(data[:len(data) - test_size]), label='Training Data')
plt.plot(np.arange(len(data) - test_size, len(data), 1),scaler.inverse_transform(data[-test_size:]), label='Testing Data')
plt.plot(np.arange(len(data) - test_size, len(data), 1), dynamic_prediction[-test_size:], label='Out of Sample Prediction')
plt.legend(loc = "upper left")

# %%
plt.figure()


plt.plot(scaler.inverse_transform(data[:-100]), label='Training Data')



plt.plot(np.arange(len(data) - test_size, len(data), 1),scaler.inverse_transform(data[-test_size:]), label='Testing Data')



#plt.plot(np.arange(len(data) - test_size, len(data), 1),scaler.inverse_transform(data[-test_size:]), label='Testing Data')

# %%
Ytest
dynamic_prediction[-test_size:]
# Out:
# array([[6118.00239505],
#        [6115.322821  ],
#        [6112.82609512],
#        [6112.07844401],
#        [6111.45496943]])

# %%
testScore = rmse(scaler.inverse_transform(Ytest.reshape(-1, 1)),dynamic_prediction[-test_size:])
print('Dynamic Forecast RMSE: {0:.2f}'.format(testScore))
# Out:
# Dynamic Forecast RMSE: 23.48

# %% [markdown]
# # Monthly

# %%
validation_size = 5

train_size = len(close_monthly) - validation_size

# %%
train_close_monthly = close_monthly[:-validation_size]
validation_close_monthly  =  close_monthly[-validation_size:]
validation_close_monthly
validate_time = validation_close_monthly.index[0]

# %% [markdown]
# # Holt's linear model

# %%
from statsmodels.tsa.holtwinters import Holt
fit4 = Holt(train_close_monthly).fit()
smooth_Holt = fit4.fittedvalues


results = pd.DataFrame(index=[r"$\alpha$", 
                              r"$\beta$", 
                              r"$\phi$",  # damped value
                              r"$\gamma$", 
                              r"$l_0$", 
                              "$b_0$", 
                              "SSE"])
params = ['smoothing_level', 
          'smoothing_slope', 
          'damping_slope', 
          'smoothing_seasonal', 
          'initial_level', 
          'initial_slope']

results["Additive"] = [fit4.params[p] for p in params] + [fit4.sse]
results
# Out:
#               Additive
# $\alpha$  1.000000e+00
# $\beta$   0.000000e+00
# $\phi$             NaN
# $\gamma$           NaN
# $l_0$     3.103576e+03
# $b_0$     1.222738e+01
# SSE       6.598045e+06

# %%
smooth_Holt
# Out:
# Date
# 2000-03-31    3115.803706
# 2000-04-30    3128.027430
# 2000-05-31    3093.227381
# 2000-06-30    3323.427332
# 2000-07-31    3263.327479
# 2000-08-31    3310.027430
# 2000-09-30    3311.027430
# 2000-10-31    3266.827479
# 2000-11-30    3286.827479
# 2000-12-31    3218.427332
# 2001-01-31    3353.927332
# 2001-02-28    3338.727381
# 2001-03-31    3159.427332
# 2001-04-30    3341.627283
# 2001-05-31    3391.327479
# 2001-06-30    3502.527430
# 2001-07-31    3336.727381
# 2001-08-31    3287.827479
# 2001-09-30    3061.727381
# 2001-10-31    3261.827479
# 2001-11-30    3349.727381
# 2001-12-31    3434.527430
# 2002-01-31    3476.427332
# 2002-02-28    3426.527430
# 2002-03-31    3427.027430
# 2002-04-30    3362.227381
# 2002-05-31    3385.827479
# 2002-06-30    3228.227381
# 2002-07-31    3098.427332
# 2002-08-31    3132.327479
#                  ...
# 2016-04-30    5264.427576
# 2016-05-31    5390.827479
# 2016-06-30    5245.627283
# 2016-07-31    5574.527186
# 2016-08-31    5445.227381
# 2016-09-30    5448.127283
# 2016-10-31    5329.927576
# 2016-11-30    5452.727381
# 2016-12-31    5678.027186
# 2017-01-31    5633.127283
# 2017-02-28    5724.427576
# 2017-03-31    5877.127283
# 2017-04-30    5936.327479
# 2017-05-31    5736.827479
# 2017-06-30    5733.727381
# 2017-07-31    5732.827479
# 2017-08-31    5726.727381
# 2017-09-30    5693.827479
# 2017-10-31    5921.227381
# 2017-11-30    5982.127283
# 2017-12-31    6077.327479
# 2018-01-31    6049.927576
# 2018-02-28    6028.227381
# 2018-03-31    5771.627283
# 2018-04-30    5994.927576
# 2018-05-31    6024.127283
# 2018-06-30    6206.827479
# 2018-07-31    6292.427576
# 2018-08-31    6331.727381
# 2018-09-30    6219.827479
# Length: 223, dtype: float64

# %%
close_monthly
# Out:
# Date
# 2000-03-31    3115.800049
# 2000-04-30    3081.000000
# 2000-05-31    3311.199951
# 2000-06-30    3251.100098
# 2000-07-31    3297.800049
# 2000-08-31    3298.800049
# 2000-09-30    3254.600098
# 2000-10-31    3274.600098
# 2000-11-30    3206.199951
# 2000-12-31    3341.699951
# 2001-01-31    3326.500000
# 2001-02-28    3147.199951
# 2001-03-31    3329.399902
# 2001-04-30    3379.100098
# 2001-05-31    3490.300049
# 2001-06-30    3324.500000
# 2001-07-31    3275.600098
# 2001-08-31    3049.500000
# 2001-09-30    3249.600098
# 2001-10-31    3337.500000
# 2001-11-30    3422.300049
# 2001-12-31    3464.199951
# 2002-01-31    3414.300049
# 2002-02-28    3414.800049
# 2002-03-31    3350.000000
# 2002-04-30    3373.600098
# 2002-05-31    3216.000000
# 2002-06-30    3086.199951
# 2002-07-31    3120.100098
# 2002-08-31    2970.899902
#                  ...
# 2016-09-30    5317.700195
# 2016-10-31    5440.500000
# 2016-11-30    5665.799805
# 2016-12-31    5620.899902
# 2017-01-31    5712.200195
# 2017-02-28    5864.899902
# 2017-03-31    5924.100098
# 2017-04-30    5724.600098
# 2017-05-31    5721.500000
# 2017-06-30    5720.600098
# 2017-07-31    5714.500000
# 2017-08-31    5681.600098
# 2017-09-30    5909.000000
# 2017-10-31    5969.899902
# 2017-11-30    6065.100098
# 2017-12-31    6037.700195
# 2018-01-31    6016.000000
# 2018-02-28    5759.399902
# 2018-03-31    5982.700195
# 2018-04-30    6011.899902
# 2018-05-31    6194.600098
# 2018-06-30    6280.200195
# 2018-07-31    6319.500000
# 2018-08-31    6207.600098
# 2018-09-30    5830.299805
# 2018-10-31    5667.200195
# 2018-11-30    5646.399902
# 2018-12-31    5864.700195
# 2019-01-31    6169.000000
# 2019-03-01    6192.700195
# Name: Close, Length: 228, dtype: float64

# %%
forecast_set = pd.Series(fit4.forecast(validation_size))

forecast_set.index = validation_close_monthly.index
forecast_set
# Out:
# Date
# 2018-10-31    5842.527186
# 2018-11-30    5854.754567
# 2018-12-31    5866.981948
# 2019-01-31    5879.209329
# 2019-03-01    5891.436710
# dtype: float64

# %%
plt.figure()
plt.title('Holt Linear Model')
plt.plot(close_monthly,label='Close monthly')
plt.plot(smooth_Holt,linestyle='--',label='Holt linear')
plt.legend();

# %%
plt.figure()
plt.plot(fit4.resid)
plt.show()

# %%
plt.figure()
plt.plot(close_monthly[-50:])
plt.plot(smooth_Holt[-45:])
plt.plot(forecast_set)
plt.show()
# Out:
# Date
# 2018-10-31    5846.778737
# 2018-11-30    5863.304246
# 2018-12-31    5879.876463
# 2019-01-31    5896.495520
# 2019-03-01    5913.161549
# dtype: float64

# %%
print("RMSE of train set for HOLT\n{:.2f}".format(rmse(smooth_Holt,train_close_monthly)))
# Out:
# RMSE of train set for HOLT
# 172.01

# %%
validation_set = close_monthly[-validation_size:].values
print("RMSE for Holt’s linear method on validation set\n{:.2f}".format(rmse(forecast_set,validation_set)))
# Out:
# RMSE for Holt’s linear method on validation set
# 223.11

# %% [markdown]
# # ARIMA

# %%
close_monthly_log = np.log(close_monthly)
train_close_monthly_log = np.log(train_close_monthly)
validation_close_monthly_log = np.log(validation_close_monthly)


plt.figure()
plt.grid()
plt.plot(train_close_monthly_log);

# %%
smt.graphics.tsa.plot_acf(train_close_monthly_log, lags=30, alpha = 0.05)
smt.graphics.tsa.plot_pacf(train_close_monthly_log, lags=30, alpha = 0.05)
plt.show()

# %%
train_close_monthly_log_diff = train_close_monthly_log.diff()
train_close_monthly_log_diff.dropna(inplace = True)
plt.figure(figsize = (16,5))
plt.plot(train_close_monthly_log_diff);

# %%
smt.graphics.tsa.plot_acf(train_close_monthly_log_diff, lags=30, alpha = 0.05)
smt.graphics.tsa.plot_pacf(train_close_monthly_log_diff, lags=30, alpha = 0.05)
plt.show()

# %%
test_stationarity(train_close_monthly_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.365881e+01
# p-value                        1.535389e-25
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.210000e+02
# Critical Value (1%)           -3.460291e+00
# Critical Value (5%)           -2.874709e+00
# Critical Value (10%)          -2.573789e+00
# dtype: float64

# %%
import statsmodels.tsa.stattools as st
order = st.arma_order_select_ic(train_close_monthly_log_diff, max_ar = 5, max_ma = 5, ic=['aic'])
print(order.aic_min_order)
# Out:
# (0, 0)

# %%
from statsmodels.tsa.arima_model import ARIMA

p,q = order.aic_min_order[0], order.aic_min_order[1]
model_AIC = ARIMA(train_close_monthly_log, order = (p, 1, q))  
results_AIC_ARIMA = model_AIC.fit(disp = -1)

# %%
residuals = pd.DataFrame(results_AIC_ARIMA.resid) 

# check the residual
plt.figure() 
plt.plot(residuals)
plt.title('ARIMA(0,1,0) RSS: %.2f'% sum((results_AIC_ARIMA.resid.values)**2)); # residual sum of square

# %%
fitted_log = results_AIC_ARIMA.predict(typ = 'levels', dynamic = False)

# Actual vs Fitted 
results_AIC_ARIMA.plot_predict(dynamic = False) 
plt.show()

# %%
fitted = np.exp(fitted_log)
forecast, stderr, conf_int = results_AIC_ARIMA.forecast(steps = validation_size)
forecast_set = pd.Series(np.exp(forecast), index = validation_close_monthly.index)
plt.figure()
plt.plot(close_monthly)
plt.plot(fitted)
plt.plot(forecast_set)
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.plot(close_monthly[-50:])
plt.plot(fitted[-43:])
plt.plot(forecast_set);

# %%
print("RMSE of train set for ARIMA\n{:.2f}".format(rmse(fitted,train_close_monthly[:-1])))
train_close_monthly
# Out:
# RMSE of train set for ARIMA
# 13.38
# Date
# 2000-03-31    3115.800049
# 2000-04-30    3081.000000
# 2000-05-31    3311.199951
# 2000-06-30    3251.100098
# 2000-07-31    3297.800049
# 2000-08-31    3298.800049
# 2000-09-30    3254.600098
# 2000-10-31    3274.600098
# 2000-11-30    3206.199951
# 2000-12-31    3341.699951
# 2001-01-31    3326.500000
# 2001-02-28    3147.199951
# 2001-03-31    3329.399902
# 2001-04-30    3379.100098
# 2001-05-31    3490.300049
# 2001-06-30    3324.500000
# 2001-07-31    3275.600098
# 2001-08-31    3049.500000
# 2001-09-30    3249.600098
# 2001-10-31    3337.500000
# 2001-11-30    3422.300049
# 2001-12-31    3464.199951
# 2002-01-31    3414.300049
# 2002-02-28    3414.800049
# 2002-03-31    3350.000000
# 2002-04-30    3373.600098
# 2002-05-31    3216.000000
# 2002-06-30    3086.199951
# 2002-07-31    3120.100098
# 2002-08-31    2970.899902
#                  ...
# 2016-04-30    5378.600098
# 2016-05-31    5233.399902
# 2016-06-30    5562.299805
# 2016-07-31    5433.000000
# 2016-08-31    5435.899902
# 2016-09-30    5317.700195
# 2016-10-31    5440.500000
# 2016-11-30    5665.799805
# 2016-12-31    5620.899902
# 2017-01-31    5712.200195
# 2017-02-28    5864.899902
# 2017-03-31    5924.100098
# 2017-04-30    5724.600098
# 2017-05-31    5721.500000
# 2017-06-30    5720.600098
# 2017-07-31    5714.500000
# 2017-08-31    5681.600098
# 2017-09-30    5909.000000
# 2017-10-31    5969.899902
# 2017-11-30    6065.100098
# 2017-12-31    6037.700195
# 2018-01-31    6016.000000
# 2018-02-28    5759.399902
# 2018-03-31    5982.700195
# 2018-04-30    6011.899902
# 2018-05-31    6194.600098
# 2018-06-30    6280.200195
# 2018-07-31    6319.500000
# 2018-08-31    6207.600098
# 2018-09-30    5830.299805
# Name: Close, Length: 223, dtype: float64

# %%
train_close_monthly[:-1]
# Out:
# Date
# 2000-03-31    3115.800049
# 2000-04-30    3081.000000
# 2000-05-31    3311.199951
# 2000-06-30    3251.100098
# 2000-07-31    3297.800049
# 2000-08-31    3298.800049
# 2000-09-30    3254.600098
# 2000-10-31    3274.600098
# 2000-11-30    3206.199951
# 2000-12-31    3341.699951
# 2001-01-31    3326.500000
# 2001-02-28    3147.199951
# 2001-03-31    3329.399902
# 2001-04-30    3379.100098
# 2001-05-31    3490.300049
# 2001-06-30    3324.500000
# 2001-07-31    3275.600098
# 2001-08-31    3049.500000
# 2001-09-30    3249.600098
# 2001-10-31    3337.500000
# 2001-11-30    3422.300049
# 2001-12-31    3464.199951
# 2002-01-31    3414.300049
# 2002-02-28    3414.800049
# 2002-03-31    3350.000000
# 2002-04-30    3373.600098
# 2002-05-31    3216.000000
# 2002-06-30    3086.199951
# 2002-07-31    3120.100098
# 2002-08-31    2970.899902
#                  ...
# 2016-03-31    5252.200195
# 2016-04-30    5378.600098
# 2016-05-31    5233.399902
# 2016-06-30    5562.299805
# 2016-07-31    5433.000000
# 2016-08-31    5435.899902
# 2016-09-30    5317.700195
# 2016-10-31    5440.500000
# 2016-11-30    5665.799805
# 2016-12-31    5620.899902
# 2017-01-31    5712.200195
# 2017-02-28    5864.899902
# 2017-03-31    5924.100098
# 2017-04-30    5724.600098
# 2017-05-31    5721.500000
# 2017-06-30    5720.600098
# 2017-07-31    5714.500000
# 2017-08-31    5681.600098
# 2017-09-30    5909.000000
# 2017-10-31    5969.899902
# 2017-11-30    6065.100098
# 2017-12-31    6037.700195
# 2018-01-31    6016.000000
# 2018-02-28    5759.399902
# 2018-03-31    5982.700195
# 2018-04-30    6011.899902
# 2018-05-31    6194.600098
# 2018-06-30    6280.200195
# 2018-07-31    6319.500000
# 2018-08-31    6207.600098
# Name: Close, Length: 222, dtype: float64

# %%
print("RMSE of test set for ARIMA\n{:.2f}".format(rmse(forecast_set,validation_set)))
# Out:
# RMSE of test set for ARIMA
# 215.37

# %% [markdown]
# ## NN

# %%
scaler = MinMaxScaler()
close_monthly_normalize = scaler.fit_transform(close_monthly.values.reshape(-1,1))
close_monthly_normalize = scaler.fit_transform(close_monthly.values.reshape(-1,1))

plt.figure(figsize = (16,5))
plt.plot(close_monthly_normalize)
plt.title("MinMaxScaler monthly close")
plt.xlabel("Time")
plt.ylabel("Close");

# %%
data = close_monthly_normalize
time_window = 5
Xall, Yall = [], []
for i in range(time_window, len(data)):
    Xall.append(data[i-time_window:i, 0])
    Yall.append(data[i, 0])
    
Xall = np.array(Xall) # Convert them from list to array
Yall = np.array(Yall)
test_size = 5
train_size =  len(Xall) - test_size

Xtrain = Xall[:train_size, :]
Ytrain = Yall[:train_size]
Xtest = Xall[-test_size:, :]
Ytest = Yall[-test_size:]

# %%
model = Sequential()
model.add(Dense(20, input_dim=time_window,activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.fit(Xtrain, Ytrain, epochs=100, batch_size=2,verbose=2, validation_split=0.05)
# Out:
# Train on 207 samples, validate on 11 samples
# Epoch 1/100
#  - 0s - loss: 0.0037 - val_loss: 0.0036
# Epoch 2/100
#  - 0s - loss: 0.0029 - val_loss: 0.0034
# Epoch 3/100
#  - 0s - loss: 0.0028 - val_loss: 0.0027
# Epoch 4/100
#  - 0s - loss: 0.0028 - val_loss: 0.0028
# Epoch 5/100
#  - 0s - loss: 0.0027 - val_loss: 0.0025
# Epoch 6/100
#  - 0s - loss: 0.0027 - val_loss: 0.0025
# Epoch 7/100
#  - 0s - loss: 0.0025 - val_loss: 0.0026
# Epoch 8/100
#  - 0s - loss: 0.0026 - val_loss: 0.0038
# Epoch 9/100
#  - 0s - loss: 0.0029 - val_loss: 0.0029
# Epoch 10/100
#  - 0s - loss: 0.0028 - val_loss: 0.0033
# Epoch 11/100
#  - 0s - loss: 0.0027 - val_loss: 0.0034
# Epoch 12/100
#  - 0s - loss: 0.0025 - val_loss: 0.0058
# Epoch 13/100
#  - 0s - loss: 0.0027 - val_loss: 0.0024
# Epoch 14/100
#  - 0s - loss: 0.0024 - val_loss: 0.0036
# Epoch 15/100
#  - 0s - loss: 0.0027 - val_loss: 0.0026
# Epoch 16/100
#  - 0s - loss: 0.0024 - val_loss: 0.0030
# Epoch 17/100
#  - 0s - loss: 0.0027 - val_loss: 0.0023
# Epoch 18/100
#  - 0s - loss: 0.0026 - val_loss: 0.0022
# Epoch 19/100
#  - 0s - loss: 0.0024 - val_loss: 0.0025
# Epoch 20/100
#  - 0s - loss: 0.0024 - val_loss: 0.0030
# Epoch 21/100
#  - 0s - loss: 0.0027 - val_loss: 0.0022
# Epoch 22/100
#  - 0s - loss: 0.0023 - val_loss: 0.0026
# Epoch 23/100
#  - 0s - loss: 0.0026 - val_loss: 0.0026
# Epoch 24/100
#  - 0s - loss: 0.0026 - val_loss: 0.0022
# Epoch 25/100
#  - 0s - loss: 0.0023 - val_loss: 0.0023
# Epoch 26/100
#  - 0s - loss: 0.0022 - val_loss: 0.0022
# Epoch 27/100
#  - 0s - loss: 0.0025 - val_loss: 0.0022
# Epoch 28/100
#  - 0s - loss: 0.0023 - val_loss: 0.0025
# Epoch 29/100
#  - 0s - loss: 0.0023 - val_loss: 0.0024
# Epoch 30/100
#  - 0s - loss: 0.0023 - val_loss: 0.0021
# Epoch 31/100
#  - 0s - loss: 0.0024 - val_loss: 0.0026
# Epoch 32/100
#  - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 33/100
#  - 0s - loss: 0.0024 - val_loss: 0.0022
# Epoch 34/100
#  - 0s - loss: 0.0023 - val_loss: 0.0021
# Epoch 35/100
#  - 0s - loss: 0.0021 - val_loss: 0.0028
# Epoch 36/100
#  - 0s - loss: 0.0024 - val_loss: 0.0021
# Epoch 37/100
#  - 0s - loss: 0.0022 - val_loss: 0.0026
# Epoch 38/100
#  - 0s - loss: 0.0022 - val_loss: 0.0021
# Epoch 39/100
#  - 0s - loss: 0.0023 - val_loss: 0.0028
# Epoch 40/100
#  - 0s - loss: 0.0022 - val_loss: 0.0042
# Epoch 41/100
#  - 0s - loss: 0.0022 - val_loss: 0.0023
# Epoch 42/100
#  - 0s - loss: 0.0023 - val_loss: 0.0020
# Epoch 43/100
#  - 0s - loss: 0.0021 - val_loss: 0.0033
# Epoch 44/100
#  - 0s - loss: 0.0025 - val_loss: 0.0023
# Epoch 45/100
#  - 0s - loss: 0.0022 - val_loss: 0.0022
# Epoch 46/100
#  - 0s - loss: 0.0023 - val_loss: 0.0025
# Epoch 47/100
#  - 0s - loss: 0.0022 - val_loss: 0.0020
# Epoch 48/100
#  - 0s - loss: 0.0024 - val_loss: 0.0020
# Epoch 49/100
#  - 0s - loss: 0.0024 - val_loss: 0.0029
# Epoch 50/100
#  - 0s - loss: 0.0020 - val_loss: 0.0021
# Epoch 51/100
#  - 0s - loss: 0.0021 - val_loss: 0.0031
# Epoch 52/100
#  - 0s - loss: 0.0022 - val_loss: 0.0026
# Epoch 53/100
#  - 0s - loss: 0.0021 - val_loss: 0.0029
# Epoch 54/100
#  - 0s - loss: 0.0022 - val_loss: 0.0023
# Epoch 55/100
#  - 0s - loss: 0.0020 - val_loss: 0.0020
# Epoch 56/100
#  - 0s - loss: 0.0024 - val_loss: 0.0026
# Epoch 57/100
#  - 0s - loss: 0.0023 - val_loss: 0.0020
# Epoch 58/100
#  - 0s - loss: 0.0022 - val_loss: 0.0022
# Epoch 59/100
#  - 0s - loss: 0.0022 - val_loss: 0.0023
# Epoch 60/100
#  - 0s - loss: 0.0026 - val_loss: 0.0021
# Epoch 61/100
#  - 0s - loss: 0.0021 - val_loss: 0.0028
# Epoch 62/100
#  - 0s - loss: 0.0022 - val_loss: 0.0019
# Epoch 63/100
#  - 0s - loss: 0.0021 - val_loss: 0.0020
# Epoch 64/100
#  - 0s - loss: 0.0022 - val_loss: 0.0024
# Epoch 65/100
#  - 0s - loss: 0.0023 - val_loss: 0.0021
# Epoch 66/100
#  - 0s - loss: 0.0021 - val_loss: 0.0020
# Epoch 67/100
#  - 0s - loss: 0.0020 - val_loss: 0.0019
# Epoch 68/100
#  - 0s - loss: 0.0021 - val_loss: 0.0020
# Epoch 69/100
#  - 0s - loss: 0.0021 - val_loss: 0.0033
# Epoch 70/100
#  - 0s - loss: 0.0021 - val_loss: 0.0034
# Epoch 71/100
#  - 0s - loss: 0.0022 - val_loss: 0.0023
# Epoch 72/100
#  - 0s - loss: 0.0021 - val_loss: 0.0020
# Epoch 73/100
#  - 0s - loss: 0.0023 - val_loss: 0.0022
# Epoch 74/100
#  - 0s - loss: 0.0022 - val_loss: 0.0030
# Epoch 75/100
#  - 0s - loss: 0.0020 - val_loss: 0.0023
# Epoch 76/100
#  - 0s - loss: 0.0021 - val_loss: 0.0019
# Epoch 77/100
#  - 0s - loss: 0.0023 - val_loss: 0.0032
# Epoch 78/100
#  - 0s - loss: 0.0020 - val_loss: 0.0019
# Epoch 79/100
#  - 0s - loss: 0.0021 - val_loss: 0.0033
# Epoch 80/100
#  - 0s - loss: 0.0022 - val_loss: 0.0020
# Epoch 81/100
#  - 0s - loss: 0.0020 - val_loss: 0.0024
# Epoch 82/100
#  - 0s - loss: 0.0021 - val_loss: 0.0020
# Epoch 83/100
#  - 0s - loss: 0.0020 - val_loss: 0.0035
# Epoch 84/100
#  - 0s - loss: 0.0021 - val_loss: 0.0020
# Epoch 85/100
#  - 0s - loss: 0.0022 - val_loss: 0.0021
# Epoch 86/100
#  - 0s - loss: 0.0021 - val_loss: 0.0026
# Epoch 87/100
#  - 0s - loss: 0.0021 - val_loss: 0.0021
# Epoch 88/100
#  - 0s - loss: 0.0022 - val_loss: 0.0019
# Epoch 89/100
#  - 0s - loss: 0.0021 - val_loss: 0.0040
# Epoch 90/100
#  - 0s - loss: 0.0023 - val_loss: 0.0024
# Epoch 91/100
#  - 0s - loss: 0.0022 - val_loss: 0.0028
# Epoch 92/100
#  - 0s - loss: 0.0020 - val_loss: 0.0020
# Epoch 93/100
#  - 0s - loss: 0.0020 - val_loss: 0.0032
# Epoch 94/100
#  - 0s - loss: 0.0020 - val_loss: 0.0026
# Epoch 95/100
#  - 0s - loss: 0.0023 - val_loss: 0.0020
# Epoch 96/100
#  - 0s - loss: 0.0024 - val_loss: 0.0019
# Epoch 97/100
#  - 0s - loss: 0.0021 - val_loss: 0.0031
# Epoch 98/100
#  - 0s - loss: 0.0020 - val_loss: 0.0019
# Epoch 99/100
#  - 0s - loss: 0.0020 - val_loss: 0.0019
# Epoch 100/100
#  - 0s - loss: 0.0022 - val_loss: 0.0019

# %%
allPredict = model.predict(Xall)
allPredictPlot = scaler.inverse_transform(allPredict)
plt.figure()
plt.plot(scaler.inverse_transform(data), label='True Data')
plt.plot(np.arange(time_window, len(data)),allPredictPlot, label='One-Step Prediction')
plt.legend(); 
Ytrain.shape
# Out:
# (218,)

# %%
Ytrain_ = scaler.inverse_transform(Ytrain.reshape(-1, 1))
allPredict_ = scaler.inverse_transform(allPredict[:train_size,0].reshape(-1, 1))
print("RMSE of train set for NN\n",rmse(Ytrain_,allPredict_))
# Out:
# RMSE of train set for NN
#  170.926931687198

# %%
dynamic_prediction = np.copy(data[:len(data) - test_size])
for i in range(len(data) - test_size, len(data)):
    last_feature = np.reshape(dynamic_prediction[i-time_window:i], (1,time_window))
    next_pred = model.predict(last_feature)
    dynamic_prediction = np.append(dynamic_prediction, next_pred)
    
dynamic_prediction = dynamic_prediction.reshape(-1,1)
dynamic_prediction = scaler.inverse_transform(dynamic_prediction)

# %%
plt.figure()
plt.plot(scaler.inverse_transform(data[:len(data) - test_size]), label='Training Data')
plt.plot(np.arange(len(data) - test_size, len(data), 1),scaler.inverse_transform(data[-test_size:]), label='Testing Data')
plt.plot(np.arange(len(data) - test_size, len(data), 1), dynamic_prediction[-test_size:], label='Out of Sample Prediction')
plt.legend(loc = "upper left")

# %%
Ytest
dynamic_prediction[-test_size:]
# Out:
# array([[5791.11297562],
#        [5702.68915262],
#        [5635.93755112],
#        [5567.94913251],
#        [5529.01943621]])

# %%
testScore = rmse(scaler.inverse_transform(Ytest.reshape(-1, 1)),dynamic_prediction[-test_size:])
print('Dynamic Forecast RMSE: {0:.2f}'.format(testScore))
# Out:
# Dynamic Forecast RMSE: 417.75
